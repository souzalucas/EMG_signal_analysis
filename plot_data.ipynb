# %%
# %matplotlib inline
import csv
import numpy as np
import pandas as pd
from numpy import genfromtxt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from scipy.signal import resample

# %%
trial_1_data = genfromtxt('./Delsys_8Chans_15Classes/S1-Delsys-15Class/HC_1.csv', delimiter=',')
trial_2_data = genfromtxt('./Delsys_8Chans_15Classes/S1-Delsys-15Class/HC_2.csv', delimiter=',')
trial_3_data = genfromtxt('./Delsys_8Chans_15Classes/S1-Delsys-15Class/HC_3.csv', delimiter=',')

# %%
d1 = list()
d2 = list()
d3 = list()

for e in range(8):
    for i, t in enumerate(np.linspace(0, 5, 20000)):
        d1.append([e, t, trial_1_data[i,e]])
        d2.append([e, t, trial_2_data[i,e]])
        d3.append([e, t, trial_3_data[i,e]])
   
d1 = np.array(d1)
d1 = resample (d1, 12000)
d2 = np.array(d2)
d2 = resample (d2, 12000)
d3 = np.array(d3)
d3 = resample (d3, 12000)

x1, y1, z1 = d1[:,0], d1[:,1], d1[:,2]
x2, y2, z2 = d2[:,0], d2[:,1], d2[:,2]
x3, y3, z3 = d3[:,0], d3[:,1], d3[:,2]

fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 3, 1, projection='3d')
surf = ax.plot_trisurf(x1, y1, z1, cmap=cm.inferno, linewidth=1)
ax.set_xlabel('Canais')
ax.set_ylabel('Tempo (seg.)')
ax.set_zlabel('Milivolts')

ax = fig.add_subplot(1, 3, 2, projection='3d')
surf = ax.plot_trisurf(x2, y2, z2, cmap=cm.inferno, linewidth=1)
ax.set_xlabel('Canais')
ax.set_ylabel('Tempo (seg.)')
ax.set_zlabel('Milivolts')

ax = fig.add_subplot(1, 3, 3, projection='3d')
surf = ax.plot_trisurf(x3, y3, z3, cmap=cm.inferno, linewidth=1)
ax.set_xlabel('Canais')
ax.set_ylabel('Tempo (seg.)')
ax.set_zlabel('Milivolts')

fig.colorbar(surf)
fig.tight_layout()
plt.show()
